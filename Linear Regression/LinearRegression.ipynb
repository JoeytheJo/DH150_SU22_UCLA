# %%
import sklearn.datasets
import pandas as pd

diabetes = sklearn.datasets.load_diabetes()

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
x = diabetes.data
y = diabetes.target

# %%
#Make a scatter plot using just one of the features in x vs the target variable y
age = x[:,0] #getting the first feature's arrays

# %%
diabetesDict = {
    'Age' : age,
    'Target' : y
} #create dictionary with age and target data

df1 = pd.DataFrame(diabetesDict) #create data frame for scatter plot
df1.plot.scatter(x = 'Age', y = 'Target') #create scatter plot
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Target'>

# %%
#More plots with other features
#adding other features to dictionary
sex = x[:,1]
bmi = x[:,2]
tc = x[:,3]
ldl = x[:,4]
hdl = x[:,5]
tch = x[:,6]
ltg = x[:,7]
glu = x[:,8]

diabetesDict = {
    'Age' : age,
    'Sex' : sex,
    'BMI' : bmi,
    'TC' : tc,
    'LDL' : ldl,
    'HDL' : hdl,
    'TCH' : tch,
    'LTG' : ltg,
    'GLU' : glu,
    'Target' : y
}

# %%
df3 = pd.DataFrame(diabetesDict)
df3.plot.scatter(x = 'BMI', y = 'Target')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Target'>

# %%
df3.plot.scatter(x = 'TC', y = 'Target')
# Out:
# <AxesSubplot:xlabel='TC', ylabel='Target'>

# %%
df3.plot.scatter(x = 'LDL', y = 'Target')
# Out:
# <AxesSubplot:xlabel='LDL', ylabel='Target'>

# %%
df3.plot.scatter(x = 'HDL', y = 'Target')
# Out:
# <AxesSubplot:xlabel='HDL', ylabel='Target'>

# %%
df3.plot.scatter(x = 'TCH', y = 'Target')
# Out:
# <AxesSubplot:xlabel='TCH', ylabel='Target'>

# %%
df3.plot.scatter(x = 'LTG', y = 'Target')
# Out:
# <AxesSubplot:xlabel='LTG', ylabel='Target'>

# %%
#GLU has GOOD RELATIONSHIP with y for classification
df3.plot.scatter(x = 'GLU', y = 'Target')
# Out:
# <AxesSubplot:xlabel='GLU', ylabel='Target'>

# %%
#Do regression with linear regression for GLU
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model
import sklearn.model_selection

#change data into a 2-D array format
x = df3['GLU']
y = df3[['Target']]

# %%
model = sklearn.linear_model.LinearRegression()

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
x_test = x_test.values.reshape(-1,1)
x_train = x_train.values.reshape(-1,1)

# %%
# Train the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Print the coefficients of model 
print(model.coef_)
# Out:
# [[901.23555388]]

# %%
# Make a prediction
x_sample = x_test
y_pred = model.predict(x_test)

# %%
#Scatter plot and linear fit for training data
plt.plot(x_train,y_train,'bo')

x_new = np.linspace(0,0.15,100000)
x_new = x_new.reshape(-1,1)

y_pred = model.intercept_ + model.coef_ * x_new

plt.plot(x_new, y_pred)

plt.show()

# %%
#Scatter plot and linear fit for test data

plt.plot(x_test,y_test, 'ko')

x_new = np.linspace(-0.15,0.15,100000)
x_new = x_new.reshape(-1,1)

y_pred = model.intercept_ + model.coef_ * x_new

plt.plot(x_new, y_pred)

plt.show()

# %%
#Mean Squared Error and R-squared values for fit
from sklearn.metrics import mean_squared_error, r2_score

print('MSE = ', mean_squared_error(y_test, model.predict(x_test)))
print('R^2 = ', r2_score(y_test, model.predict(x_test)))
# Out:
# MSE =  3270.5689613353848
# R^2 =  0.38269624643139144

# %%
#Do regression with linear regression for BMI
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model
import sklearn.model_selection

#change data into a 2-D array format
x = df3['BMI']
y = df3[['Target']]

# %%
model = sklearn.linear_model.LinearRegression()

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
x_test = x_test.values.reshape(-1,1)
x_train = x_train.values.reshape(-1,1)

# %%
# Train the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Print the coefficients of model 
print(model.coef_)
# Out:
# [[998.57768914]]

# %%
# Make a prediction
x_sample = x_test
y_pred = model.predict(x_test)

# %%
#Scatter plot and linear fit for training data
plt.plot(x_train,y_train,'bo')

x_new = np.linspace(0,0.15,100000)
x_new = x_new.reshape(-1,1)

y_pred = model.intercept_ + model.coef_ * x_new

plt.plot(x_new, y_pred)

plt.show()

# %%
#Scatter plot and linear fit for test data

plt.plot(x_test,y_test, 'ko')

x_new = np.linspace(-0.15,0.15,100000)
x_new = x_new.reshape(-1,1)

y_pred = model.intercept_ + model.coef_ * x_new

plt.plot(x_new, y_pred)

plt.show()

# %%
#Mean Squared Error and R-squared values for fit
from sklearn.metrics import mean_squared_error, r2_score

print('MSE = ', mean_squared_error(y_test, model.predict(x_test)))
print('R^2 = ', r2_score(y_test, model.predict(x_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_222/1980355300.py in <module>
#       2 from sklearn.metrics import mean_squared_error, r2_score
#       3
# ----> 4 print('MSE = ', mean_squared_error(y_test, model.predict(x_test)))
#       5 print('R^2 = ', r2_score(y_test, model.predict(x_test)))
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# ...

# %%
#Regression on same data set with k-nearest neighbors
import sklearn.neighbors
model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)

# %%
x = x.values.reshape(-1,1)

# %%
# Train the model
model.fit(x,y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
# Make a prediction
x_test = [[25000]]
model.predict(x_test)
# Out:
# array([[273.66666667]])

# %%
# Visualize what the predictions are for this model

plt.plot(x_train,y_train,'ko')

x_new = np.linspace(-0.1,0.15,100000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
# Visualize what the predictions are for this model

plt.plot(x_test,y_test,'ko')

x_new = np.linspace(-0.1,0.15,100000)
x_new = x_new.values.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_222/1012485384.py in <module>
#       1 # Visualize what the predictions are for this model
#       2
# ----> 3 plt.plot(x_test,y_test,'ko')
#       4
#       5 x_new = np.linspace(-0.1,0.15,100000)
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
